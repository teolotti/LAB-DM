# %%
from Bio import Entrez
import pandas as pd
from Bio import Medline
import time
from urllib.error import HTTPError, URLError
import socket
from http.client import IncompleteRead
import requests

patients_df = pd.read_csv("data/PMC-Patients.csv")
unique_pmids = patients_df["PMID"].unique()

Entrez.email = "matteo.lotti3@edu.unifi.it"
pmid_list = unique_pmids.tolist()

batch_size = 500  # Ridotto da 1000 a 500
all_records = []
failed_batches = []

print(f"Fetching data for {len(pmid_list)} PMIDs from PubMed...")

for start in range(0, len(pmid_list), batch_size):
    end = min(start + batch_size, len(pmid_list))
    batch_pmids = pmid_list[start:end]
    print(f"Fetching PMIDs {start + 1} to {end}...")
    
    max_retries = 3
    for attempt in range(max_retries):
        try:
            # Aggiungi timeout
            handle = Entrez.efetch(
                db="pubmed", 
                id=",".join(map(str, batch_pmids)), 
                rettype="medline", 
                retmode="text",
                retmax=batch_size
            )
            
            records = list(Medline.parse(handle))
            all_records.extend(records)
            print(f"✓ Batch {start//batch_size + 1} successful: {len(records)} records")
            
            # Pausa tra le richieste
            time.sleep(1)
            break  # Esci dal loop di retry se ha successo
            
        except (HTTPError, URLError, socket.timeout, IncompleteRead) as e:
            print(f"✗ Attempt {attempt + 1} failed for batch {start//batch_size + 1}: {e}")
            if attempt < max_retries - 1:
                print(f"Retrying in {2 ** attempt} seconds...")
                time.sleep(2 ** attempt)  # Backoff esponenziale
            else:
                print(f"❌ Batch {start//batch_size + 1} failed after {max_retries} attempts")
                failed_batches.append((start, end))
                continue

print(f"\n=== SUMMARY ===")
print(f"Fetched {len(all_records)} records from PubMed.")
print(f"Failed batches: {len(failed_batches)}")
print(f"Success rate: {len(all_records)/len(pmid_list)*100:.1f}%")

# Crea DataFrame SOLO se abbiamo record
if all_records:
    df = pd.DataFrame([
        {
            "PMID": rec.get("PMID", ""),
            "Title": rec.get("TI", ""),
            "Authors": "; ".join(rec.get("AU", [])),
            "Journal": rec.get("JT", ""),
            "Date": rec.get("DEP", ""),  # Data di pubblicazione elettronica
            "Abstract": rec.get("AB", ""),
            "DOI": rec.get("LID", "")
        }
        for rec in all_records
    ])
    
    # Gestione date più robusta
    def parse_date(date_str):
        if not date_str or date_str == "":
            return None
        try:
            # Prova diversi formati di data
            if len(date_str) == 8 and date_str.isdigit():
                return date_str
            else:
                return None
        except:
            return None
    
    df["Date"] = df["Date"].apply(parse_date)
    
    # Separa in colonne solo per date valide
    valid_dates = df["Date"].notna()
    df.loc[valid_dates, "Year"] = df.loc[valid_dates, "Date"].str[:4]
    df.loc[valid_dates, "Month"] = df.loc[valid_dates, "Date"].str[4:6]
    df.loc[valid_dates, "Day"] = df.loc[valid_dates, "Date"].str[6:8]
    
    print(f"\nRecords with valid dates: {valid_dates.sum()}")
    print(f"Records without dates: {(~valid_dates).sum()}")
    
    # Salva
    df.to_csv("data/pubmed_data.csv", index=False)
    print("Data saved to data/pubmed_data.csv")

    # Mostra anteprima
    print("\nFirst 10 rows:")
    print(df.head(10))
else:
    print("❌ No records were fetched!")
# Out:
# Fetching data for 140897 PMIDs from PubMed...
# Fetching PMIDs 1 to 500...
# ✓ Batch 1 successful: 500 records
# Fetching PMIDs 501 to 1000...
# ✓ Batch 2 successful: 500 records
# Fetching PMIDs 1001 to 1500...
# ✓ Batch 3 successful: 500 records
# Fetching PMIDs 1501 to 2000...
# ✓ Batch 4 successful: 499 records
# Fetching PMIDs 2001 to 2500...
# ✓ Batch 5 successful: 500 records
# Fetching PMIDs 2501 to 3000...
# ✓ Batch 6 successful: 499 records
# Fetching PMIDs 3001 to 3500...
# ✓ Batch 7 successful: 500 records
# Fetching PMIDs 3501 to 4000...
# ✓ Batch 8 successful: 500 records
# Fetching PMIDs 4001 to 4500...
# ✓ Batch 9 successful: 500 records
# Fetching PMIDs 4501 to 5000...
# ✓ Batch 10 successful: 500 records
# Fetching PMIDs 5001 to 5500...
# ✓ Batch 11 successful: 500 records
# Fetching PMIDs 5501 to 6000...
# ✓ Batch 12 successful: 500 records
# Fetching PMIDs 6001 to 6500...
# ✓ Batch 13 successful: 499 records
# Fetching PMIDs 6501 to 7000...
# ✓ Batch 14 successful: 500 records
# Fetching PMIDs 7001 to 7500...
# ✓ Batch 15 successful: 498 records
# Fetching PMIDs 7501 to 8000...
# ✓ Batch 16 successful: 500 records
# Fetching PMIDs 8001 to 8500...
# ✓ Batch 17 successful: 500 records
# Fetching PMIDs 8501 to 9000...
# ✓ Batch 18 successful: 499 records
# Fetching PMIDs 9001 to 9500...
# ✓ Batch 19 successful: 490 records
# Fetching PMIDs 9501 to 10000...
# ✓ Batch 20 successful: 494 records
# Fetching PMIDs 10001 to 10500...
# ✓ Batch 21 successful: 499 records
# Fetching PMIDs 10501 to 11000...
# ✓ Batch 22 successful: 498 records
# Fetching PMIDs 11001 to 11500...
# ✓ Batch 23 successful: 499 records
# Fetching PMIDs 11501 to 12000...
# ✓ Batch 24 successful: 497 records
# Fetching PMIDs 12001 to 12500...
# ✓ Batch 25 successful: 500 records
# Fetching PMIDs 12501 to 13000...
# ✓ Batch 26 successful: 499 records
# Fetching PMIDs 13001 to 13500...
# ✓ Batch 27 successful: 500 records
# Fetching PMIDs 13501 to 14000...
# ✓ Batch 28 successful: 500 records
# Fetching PMIDs 14001 to 14500...
# ✓ Batch 29 successful: 500 records
# Fetching PMIDs 14501 to 15000...
# ✓ Batch 30 successful: 494 records
# Fetching PMIDs 15001 to 15500...
# ✓ Batch 31 successful: 500 records
# Fetching PMIDs 15501 to 16000...
# ✓ Batch 32 successful: 500 records
# Fetching PMIDs 16001 to 16500...
# ✓ Batch 33 successful: 499 records
# Fetching PMIDs 16501 to 17000...
# ✓ Batch 34 successful: 494 records
# Fetching PMIDs 17001 to 17500...
# ✓ Batch 35 successful: 498 records
# Fetching PMIDs 17501 to 18000...
# ✓ Batch 36 successful: 498 records
# Fetching PMIDs 18001 to 18500...
# ✓ Batch 37 successful: 500 records
# Fetching PMIDs 18501 to 19000...
# ✓ Batch 38 successful: 497 records
# Fetching PMIDs 19001 to 19500...
# ✓ Batch 39 successful: 499 records
# Fetching PMIDs 19501 to 20000...
# ✓ Batch 40 successful: 489 records
# Fetching PMIDs 20001 to 20500...
# ✓ Batch 41 successful: 499 records
# Fetching PMIDs 20501 to 21000...
# ✓ Batch 42 successful: 500 records
# Fetching PMIDs 21001 to 21500...
# ✓ Batch 43 successful: 498 records
# Fetching PMIDs 21501 to 22000...
# ✓ Batch 44 successful: 500 records
# Fetching PMIDs 22001 to 22500...
# ✓ Batch 45 successful: 500 records
# Fetching PMIDs 22501 to 23000...
# ✓ Batch 46 successful: 500 records
# Fetching PMIDs 23001 to 23500...
# ✓ Batch 47 successful: 500 records
# Fetching PMIDs 23501 to 24000...
# ✓ Batch 48 successful: 500 records
# Fetching PMIDs 24001 to 24500...
# ✓ Batch 49 successful: 500 records
# Fetching PMIDs 24501 to 25000...
# ✓ Batch 50 successful: 498 records
# Fetching PMIDs 25001 to 25500...
# ✓ Batch 51 successful: 498 records
# Fetching PMIDs 25501 to 26000...
# ✓ Batch 52 successful: 499 records
# Fetching PMIDs 26001 to 26500...
# ✓ Batch 53 successful: 499 records
# Fetching PMIDs 26501 to 27000...
# ✓ Batch 54 successful: 496 records
# Fetching PMIDs 27001 to 27500...
# ✓ Batch 55 successful: 500 records
# Fetching PMIDs 27501 to 28000...
# ✓ Batch 56 successful: 495 records
# Fetching PMIDs 28001 to 28500...
# ✓ Batch 57 successful: 499 records
# Fetching PMIDs 28501 to 29000...
# ✓ Batch 58 successful: 500 records
# Fetching PMIDs 29001 to 29500...
# ✓ Batch 59 successful: 500 records
# Fetching PMIDs 29501 to 30000...
# ✓ Batch 60 successful: 500 records
# Fetching PMIDs 30001 to 30500...
# ✓ Batch 61 successful: 500 records
# Fetching PMIDs 30501 to 31000...
# ✓ Batch 62 successful: 500 records
# Fetching PMIDs 31001 to 31500...
# ✓ Batch 63 successful: 500 records
# Fetching PMIDs 31501 to 32000...
# ✓ Batch 64 successful: 500 records
# Fetching PMIDs 32001 to 32500...
# ✓ Batch 65 successful: 500 records
# Fetching PMIDs 32501 to 33000...
# ✓ Batch 66 successful: 500 records
# Fetching PMIDs 33001 to 33500...
# ✓ Batch 67 successful: 500 records
# Fetching PMIDs 33501 to 34000...
# ✓ Batch 68 successful: 500 records
# Fetching PMIDs 34001 to 34500...
# ✓ Batch 69 successful: 500 records
# Fetching PMIDs 34501 to 35000...
# ✓ Batch 70 successful: 500 records
# Fetching PMIDs 35001 to 35500...
# ✓ Batch 71 successful: 500 records
# Fetching PMIDs 35501 to 36000...
# ✓ Batch 72 successful: 500 records
# Fetching PMIDs 36001 to 36500...
# ✓ Batch 73 successful: 500 records
# Fetching PMIDs 36501 to 37000...
# ✓ Batch 74 successful: 500 records
# Fetching PMIDs 37001 to 37500...
# ✓ Batch 75 successful: 500 records
# Fetching PMIDs 37501 to 38000...
# ✓ Batch 76 successful: 500 records
# Fetching PMIDs 38001 to 38500...
# ✓ Batch 77 successful: 500 records
# Fetching PMIDs 38501 to 39000...
# ✓ Batch 78 successful: 500 records
# Fetching PMIDs 39001 to 39500...
# ✓ Batch 79 successful: 500 records
# Fetching PMIDs 39501 to 40000...
# ✓ Batch 80 successful: 500 records
# Fetching PMIDs 40001 to 40500...
# ✓ Batch 81 successful: 498 records
# Fetching PMIDs 40501 to 41000...
# ✓ Batch 82 successful: 498 records
# Fetching PMIDs 41001 to 41500...
# ✓ Batch 83 successful: 500 records
# Fetching PMIDs 41501 to 42000...
# ✓ Batch 84 successful: 500 records
# Fetching PMIDs 42001 to 42500...
# ✓ Batch 85 successful: 500 records
# Fetching PMIDs 42501 to 43000...
# ✓ Batch 86 successful: 500 records
# Fetching PMIDs 43001 to 43500...
# ✓ Batch 87 successful: 500 records
# Fetching PMIDs 43501 to 44000...
# ✓ Batch 88 successful: 500 records
# Fetching PMIDs 44001 to 44500...
# ✓ Batch 89 successful: 500 records
# Fetching PMIDs 44501 to 45000...
# ✓ Batch 90 successful: 500 records
# Fetching PMIDs 45001 to 45500...
# ✓ Batch 91 successful: 500 records
# Fetching PMIDs 45501 to 46000...
# ✓ Batch 92 successful: 500 records
# Fetching PMIDs 46001 to 46500...
# ✓ Batch 93 successful: 500 records
# Fetching PMIDs 46501 to 47000...
# ✓ Batch 94 successful: 500 records
# Fetching PMIDs 47001 to 47500...
# ✓ Batch 95 successful: 500 records
# Fetching PMIDs 47501 to 48000...
# ✓ Batch 96 successful: 500 records
# Fetching PMIDs 48001 to 48500...
# ✓ Batch 97 successful: 500 records
# Fetching PMIDs 48501 to 49000...
# ✓ Batch 98 successful: 500 records
# Fetching PMIDs 49001 to 49500...
# ✓ Batch 99 successful: 500 records
# Fetching PMIDs 49501 to 50000...
# ✓ Batch 100 successful: 500 records
# Fetching PMIDs 50001 to 50500...
# ✓ Batch 101 successful: 500 records
# Fetching PMIDs 50501 to 51000...
# ✓ Batch 102 successful: 500 records
# Fetching PMIDs 51001 to 51500...
# ✓ Batch 103 successful: 500 records
# Fetching PMIDs 51501 to 52000...
# ✓ Batch 104 successful: 500 records
# Fetching PMIDs 52001 to 52500...
# ✓ Batch 105 successful: 500 records
# Fetching PMIDs 52501 to 53000...
# ✓ Batch 106 successful: 500 records
# Fetching PMIDs 53001 to 53500...
# ✓ Batch 107 successful: 500 records
# Fetching PMIDs 53501 to 54000...
# ✓ Batch 108 successful: 500 records
# Fetching PMIDs 54001 to 54500...
# ✓ Batch 109 successful: 500 records
# Fetching PMIDs 54501 to 55000...
# ✓ Batch 110 successful: 500 records
# Fetching PMIDs 55001 to 55500...
# ✓ Batch 111 successful: 500 records
# Fetching PMIDs 55501 to 56000...
# ✓ Batch 112 successful: 500 records
# Fetching PMIDs 56001 to 56500...
# ✓ Batch 113 successful: 500 records
# Fetching PMIDs 56501 to 57000...
# ✓ Batch 114 successful: 500 records
# Fetching PMIDs 57001 to 57500...
# ✓ Batch 115 successful: 500 records
# Fetching PMIDs 57501 to 58000...
# ✓ Batch 116 successful: 500 records
# Fetching PMIDs 58001 to 58500...
# ✓ Batch 117 successful: 500 records
# Fetching PMIDs 58501 to 59000...
# ✓ Batch 118 successful: 500 records
# Fetching PMIDs 59001 to 59500...
# ✓ Batch 119 successful: 500 records
# Fetching PMIDs 59501 to 60000...
# ✓ Batch 120 successful: 500 records
# Fetching PMIDs 60001 to 60500...
# ✓ Batch 121 successful: 500 records
# Fetching PMIDs 60501 to 61000...
# ✓ Batch 122 successful: 500 records
# Fetching PMIDs 61001 to 61500...
# ✓ Batch 123 successful: 500 records
# Fetching PMIDs 61501 to 62000...
# ✓ Batch 124 successful: 500 records
# Fetching PMIDs 62001 to 62500...
# ✓ Batch 125 successful: 500 records
# Fetching PMIDs 62501 to 63000...
# ✓ Batch 126 successful: 500 records
# Fetching PMIDs 63001 to 63500...
# ✓ Batch 127 successful: 500 records
# Fetching PMIDs 63501 to 64000...
# ✓ Batch 128 successful: 500 records
# Fetching PMIDs 64001 to 64500...
# ✓ Batch 129 successful: 500 records
# Fetching PMIDs 64501 to 65000...
# ✓ Batch 130 successful: 500 records
# Fetching PMIDs 65001 to 65500...
# ✓ Batch 131 successful: 500 records
# Fetching PMIDs 65501 to 66000...
# ✓ Batch 132 successful: 500 records
# Fetching PMIDs 66001 to 66500...
# ✓ Batch 133 successful: 500 records
# Fetching PMIDs 66501 to 67000...
# ✓ Batch 134 successful: 500 records
# Fetching PMIDs 67001 to 67500...
# ✓ Batch 135 successful: 500 records
# Fetching PMIDs 67501 to 68000...
# ✓ Batch 136 successful: 500 records
# Fetching PMIDs 68001 to 68500...
# ✓ Batch 137 successful: 500 records
# Fetching PMIDs 68501 to 69000...
# ✓ Batch 138 successful: 500 records
# Fetching PMIDs 69001 to 69500...
# ✓ Batch 139 successful: 500 records
# Fetching PMIDs 69501 to 70000...
# ✓ Batch 140 successful: 500 records
# Fetching PMIDs 70001 to 70500...
# ✓ Batch 141 successful: 500 records
# Fetching PMIDs 70501 to 71000...
# ✓ Batch 142 successful: 500 records
# Fetching PMIDs 71001 to 71500...
# ✓ Batch 143 successful: 500 records
# Fetching PMIDs 71501 to 72000...
# ✓ Batch 144 successful: 500 records
# Fetching PMIDs 72001 to 72500...
# ✓ Batch 145 successful: 500 records
# Fetching PMIDs 72501 to 73000...
# ✓ Batch 146 successful: 500 records
# Fetching PMIDs 73001 to 73500...
# ✓ Batch 147 successful: 500 records
# Fetching PMIDs 73501 to 74000...
# ✓ Batch 148 successful: 500 records
# Fetching PMIDs 74001 to 74500...
# ✓ Batch 149 successful: 500 records
# Fetching PMIDs 74501 to 75000...
# ✓ Batch 150 successful: 500 records
# Fetching PMIDs 75001 to 75500...
# ✓ Batch 151 successful: 500 records
# Fetching PMIDs 75501 to 76000...
# ✓ Batch 152 successful: 500 records
# Fetching PMIDs 76001 to 76500...
# ✓ Batch 153 successful: 500 records
# Fetching PMIDs 76501 to 77000...
# ✓ Batch 154 successful: 500 records
# Fetching PMIDs 77001 to 77500...
# ✓ Batch 155 successful: 500 records
# Fetching PMIDs 77501 to 78000...
# ✓ Batch 156 successful: 500 records
# Fetching PMIDs 78001 to 78500...
# ✓ Batch 157 successful: 500 records
# Fetching PMIDs 78501 to 79000...
# ✓ Batch 158 successful: 500 records
# Fetching PMIDs 79001 to 79500...
# ✓ Batch 159 successful: 500 records
# Fetching PMIDs 79501 to 80000...
# ✓ Batch 160 successful: 500 records
# Fetching PMIDs 80001 to 80500...
# ✓ Batch 161 successful: 500 records
# Fetching PMIDs 80501 to 81000...
# ✓ Batch 162 successful: 500 records
# Fetching PMIDs 81001 to 81500...
# ✓ Batch 163 successful: 500 records
# Fetching PMIDs 81501 to 82000...
# ✓ Batch 164 successful: 500 records
# Fetching PMIDs 82001 to 82500...
# ✓ Batch 165 successful: 500 records
# Fetching PMIDs 82501 to 83000...
# ✓ Batch 166 successful: 500 records
# Fetching PMIDs 83001 to 83500...
# ✓ Batch 167 successful: 500 records
# Fetching PMIDs 83501 to 84000...
# ✓ Batch 168 successful: 500 records
# Fetching PMIDs 84001 to 84500...
# ✓ Batch 169 successful: 500 records
# Fetching PMIDs 84501 to 85000...
# ✓ Batch 170 successful: 500 records
# Fetching PMIDs 85001 to 85500...
# ✓ Batch 171 successful: 500 records
# Fetching PMIDs 85501 to 86000...
# ✓ Batch 172 successful: 500 records
# Fetching PMIDs 86001 to 86500...
# ✓ Batch 173 successful: 500 records
# Fetching PMIDs 86501 to 87000...
# ✓ Batch 174 successful: 500 records
# Fetching PMIDs 87001 to 87500...
# ✓ Batch 175 successful: 500 records
# Fetching PMIDs 87501 to 88000...
# ✓ Batch 176 successful: 500 records
# Fetching PMIDs 88001 to 88500...
# ✓ Batch 177 successful: 500 records
# Fetching PMIDs 88501 to 89000...
# ✓ Batch 178 successful: 500 records
# Fetching PMIDs 89001 to 89500...
# ✓ Batch 179 successful: 500 records
# Fetching PMIDs 89501 to 90000...
# ✓ Batch 180 successful: 500 records
# Fetching PMIDs 90001 to 90500...
# ✓ Batch 181 successful: 500 records
# Fetching PMIDs 90501 to 91000...
# ✓ Batch 182 successful: 500 records
# Fetching PMIDs 91001 to 91500...
# ✗ Attempt 1 failed for batch 183: IncompleteRead(0 bytes read)
# Retrying in 1 seconds...
# ✓ Batch 183 successful: 500 records
# Fetching PMIDs 91501 to 92000...
# ✓ Batch 184 successful: 500 records
# Fetching PMIDs 92001 to 92500...
# ✓ Batch 185 successful: 500 records
# Fetching PMIDs 92501 to 93000...
# ✓ Batch 186 successful: 500 records
# Fetching PMIDs 93001 to 93500...
# ✓ Batch 187 successful: 500 records
# Fetching PMIDs 93501 to 94000...
# ✓ Batch 188 successful: 500 records
# Fetching PMIDs 94001 to 94500...
# ✓ Batch 189 successful: 500 records
# Fetching PMIDs 94501 to 95000...
# ✓ Batch 190 successful: 500 records
# Fetching PMIDs 95001 to 95500...
# ✓ Batch 191 successful: 500 records
# Fetching PMIDs 95501 to 96000...
# ✓ Batch 192 successful: 500 records
# Fetching PMIDs 96001 to 96500...
# ✓ Batch 193 successful: 500 records
# Fetching PMIDs 96501 to 97000...
# ✓ Batch 194 successful: 500 records
# Fetching PMIDs 97001 to 97500...
# ✓ Batch 195 successful: 500 records
# Fetching PMIDs 97501 to 98000...
# ✓ Batch 196 successful: 500 records
# Fetching PMIDs 98001 to 98500...
# ✓ Batch 197 successful: 500 records
# Fetching PMIDs 98501 to 99000...
# ✓ Batch 198 successful: 500 records
# Fetching PMIDs 99001 to 99500...
# ✓ Batch 199 successful: 500 records
# Fetching PMIDs 99501 to 100000...
# ✓ Batch 200 successful: 500 records
# Fetching PMIDs 100001 to 100500...
# ✓ Batch 201 successful: 500 records
# Fetching PMIDs 100501 to 101000...
# ✓ Batch 202 successful: 500 records
# Fetching PMIDs 101001 to 101500...
# ✓ Batch 203 successful: 500 records
# Fetching PMIDs 101501 to 102000...
# ✓ Batch 204 successful: 500 records
# Fetching PMIDs 102001 to 102500...
# ✓ Batch 205 successful: 500 records
# Fetching PMIDs 102501 to 103000...
# ✓ Batch 206 successful: 500 records
# Fetching PMIDs 103001 to 103500...
# ✓ Batch 207 successful: 500 records
# Fetching PMIDs 103501 to 104000...
# ✓ Batch 208 successful: 500 records
# Fetching PMIDs 104001 to 104500...
# ✓ Batch 209 successful: 500 records
# Fetching PMIDs 104501 to 105000...
# ✓ Batch 210 successful: 500 records
# Fetching PMIDs 105001 to 105500...
# ✓ Batch 211 successful: 500 records
# Fetching PMIDs 105501 to 106000...
# ✓ Batch 212 successful: 500 records
# Fetching PMIDs 106001 to 106500...
# ✓ Batch 213 successful: 500 records
# Fetching PMIDs 106501 to 107000...
# ✓ Batch 214 successful: 500 records
# Fetching PMIDs 107001 to 107500...
# ✓ Batch 215 successful: 500 records
# Fetching PMIDs 107501 to 108000...
# ✓ Batch 216 successful: 500 records
# Fetching PMIDs 108001 to 108500...
# ✓ Batch 217 successful: 500 records
# Fetching PMIDs 108501 to 109000...
# ✓ Batch 218 successful: 500 records
# Fetching PMIDs 109001 to 109500...
# ✓ Batch 219 successful: 500 records
# Fetching PMIDs 109501 to 110000...
# ✓ Batch 220 successful: 500 records
# Fetching PMIDs 110001 to 110500...
# ✓ Batch 221 successful: 500 records
# Fetching PMIDs 110501 to 111000...
# ✓ Batch 222 successful: 500 records
# Fetching PMIDs 111001 to 111500...
# ✓ Batch 223 successful: 500 records
# Fetching PMIDs 111501 to 112000...
# ✓ Batch 224 successful: 500 records
# Fetching PMIDs 112001 to 112500...
# ✓ Batch 225 successful: 500 records
# Fetching PMIDs 112501 to 113000...
# ✓ Batch 226 successful: 500 records
# Fetching PMIDs 113001 to 113500...
# ✓ Batch 227 successful: 500 records
# Fetching PMIDs 113501 to 114000...
# ✓ Batch 228 successful: 500 records
# Fetching PMIDs 114001 to 114500...
# ✓ Batch 229 successful: 500 records
# Fetching PMIDs 114501 to 115000...
# ✓ Batch 230 successful: 500 records
# Fetching PMIDs 115001 to 115500...
# ✓ Batch 231 successful: 500 records
# Fetching PMIDs 115501 to 116000...
# ✓ Batch 232 successful: 500 records
# Fetching PMIDs 116001 to 116500...
# ✓ Batch 233 successful: 500 records
# Fetching PMIDs 116501 to 117000...
# ✓ Batch 234 successful: 500 records
# Fetching PMIDs 117001 to 117500...
# ✓ Batch 235 successful: 500 records
# Fetching PMIDs 117501 to 118000...
# ✓ Batch 236 successful: 500 records
# Fetching PMIDs 118001 to 118500...
# ✓ Batch 237 successful: 500 records
# Fetching PMIDs 118501 to 119000...
# ✓ Batch 238 successful: 500 records
# Fetching PMIDs 119001 to 119500...
# ✓ Batch 239 successful: 500 records
# Fetching PMIDs 119501 to 120000...
# ✓ Batch 240 successful: 500 records
# Fetching PMIDs 120001 to 120500...
# ✓ Batch 241 successful: 500 records
# Fetching PMIDs 120501 to 121000...
# ✓ Batch 242 successful: 500 records
# Fetching PMIDs 121001 to 121500...
# ✓ Batch 243 successful: 500 records
# Fetching PMIDs 121501 to 122000...
# ✓ Batch 244 successful: 500 records
# Fetching PMIDs 122001 to 122500...
# ✓ Batch 245 successful: 500 records
# Fetching PMIDs 122501 to 123000...
# ✓ Batch 246 successful: 500 records
# Fetching PMIDs 123001 to 123500...
# ✓ Batch 247 successful: 500 records
# Fetching PMIDs 123501 to 124000...
# ✓ Batch 248 successful: 500 records
# Fetching PMIDs 124001 to 124500...
# ✓ Batch 249 successful: 500 records
# Fetching PMIDs 124501 to 125000...
# ✓ Batch 250 successful: 500 records
# Fetching PMIDs 125001 to 125500...
# ✓ Batch 251 successful: 500 records
# Fetching PMIDs 125501 to 126000...
# ✓ Batch 252 successful: 500 records
# Fetching PMIDs 126001 to 126500...
# ✓ Batch 253 successful: 500 records
# Fetching PMIDs 126501 to 127000...
# ✓ Batch 254 successful: 500 records
# Fetching PMIDs 127001 to 127500...
# ✓ Batch 255 successful: 500 records
# Fetching PMIDs 127501 to 128000...
# ✓ Batch 256 successful: 500 records
# Fetching PMIDs 128001 to 128500...
# ✓ Batch 257 successful: 500 records
# Fetching PMIDs 128501 to 129000...
# ✓ Batch 258 successful: 500 records
# Fetching PMIDs 129001 to 129500...
# ✓ Batch 259 successful: 500 records
# Fetching PMIDs 129501 to 130000...
# ✓ Batch 260 successful: 500 records
# Fetching PMIDs 130001 to 130500...
# ✓ Batch 261 successful: 499 records
# Fetching PMIDs 130501 to 131000...
# ✓ Batch 262 successful: 500 records
# Fetching PMIDs 131001 to 131500...
# ✓ Batch 263 successful: 500 records
# Fetching PMIDs 131501 to 132000...
# ✓ Batch 264 successful: 500 records
# Fetching PMIDs 132001 to 132500...
# ✓ Batch 265 successful: 500 records
# Fetching PMIDs 132501 to 133000...
# ✓ Batch 266 successful: 500 records
# Fetching PMIDs 133001 to 133500...
# ✓ Batch 267 successful: 500 records
# Fetching PMIDs 133501 to 134000...
# ✓ Batch 268 successful: 500 records
# Fetching PMIDs 134001 to 134500...
# ✓ Batch 269 successful: 500 records
# Fetching PMIDs 134501 to 135000...
# ✓ Batch 270 successful: 500 records
# Fetching PMIDs 135001 to 135500...
# ✓ Batch 271 successful: 500 records
# Fetching PMIDs 135501 to 136000...
# ✓ Batch 272 successful: 500 records
# Fetching PMIDs 136001 to 136500...
# ✓ Batch 273 successful: 500 records
# Fetching PMIDs 136501 to 137000...
# ✓ Batch 274 successful: 500 records
# Fetching PMIDs 137001 to 137500...
# ✓ Batch 275 successful: 500 records
# Fetching PMIDs 137501 to 138000...
# ✓ Batch 276 successful: 500 records
# Fetching PMIDs 138001 to 138500...
# ✓ Batch 277 successful: 500 records
# Fetching PMIDs 138501 to 139000...
# ✓ Batch 278 successful: 500 records
# Fetching PMIDs 139001 to 139500...
# ✓ Batch 279 successful: 500 records
# Fetching PMIDs 139501 to 140000...
# ✓ Batch 280 successful: 500 records
# Fetching PMIDs 140001 to 140500...
# ✓ Batch 281 successful: 500 records
# Fetching PMIDs 140501 to 140897...
# ✓ Batch 282 successful: 397 records
#
# === SUMMARY ===
# Fetched 140811 records from PubMed.
# Failed batches: 0
# Success rate: 99.9%
#
# Records with valid dates: 108490
# Records without dates: 32321
# Data saved to data/pubmed_data.csv
#
# First 10 rows:
#        PMID                                              Title  \
# 0  33492400  Early Physical Therapist Interventions for Pat...
# 1  34956745  Deranged Liver Function Tests and Liver Insult...
# 2  34956746  Goserelin Ovarian Ablation Failure in Premenop...
# 3  34956749  Treatment of Inferior Vena Cava Thrombosis by ...
# 4  34956752  Unusual Cutaneous Location of Langheransian Hi...
# 5  34956761  Bilateral Ureteral Obstruction Causing Acute K...
# 6  34956751  De-novo Antineutrophil Cytoplasmic Antibody-As...
# 7  34956768  Metastatic Endometrial Cancer to the Sigmoid C...
# 8  34956758  An Approach for Diagnosing and Treating Neuros...
# 9  34956771  An Extremely Rare Case of Metastatic Merkel Ca...
#
#                                              Authors           Journal  \
# 0  Eggmann S; Kindler A; Perren A; Ott N; Johanne...  Physical therapy
# 1                  Pinheiro J; Jameel I; Palejwala A            Cureus
# 2                      Gupta A; Bandaru S; Manthri S            Cureus
# 3  Sarwar U; Bardia N; Patel M; Omar B; Malozzi C...            Cureus
# 4  Bendari M; Chamizakhraji I; Elamari S; Oqbani ...            Cureus
# 5                        Rashid U; Marra EM; Tran VH            Cureus
# 6  Feghali EJ; Zafar M; Abid S; Santoriello D; Me...            Cureus
# 7                         Koury E; Kawar H; Chahla E            Cureus
# 8                Glenn SJ; Haq S; Poddar K; Hunter L            Cureus
# 9                                 Thomas M; Mandal A            Cureus
#
#        Date                                           Abstract  \
# 0      None  OBJECTIVE: The aim of this case series was to ...
# 1  20211115  Anorexia nervosa (AN) is an eating disorder of...
# 2  20211115  Breast cancer is the most prevalent cancer kno...
# 3  20211115  Optimal treatment of inferior vena cava (IVC) ...
# 4  20211116  Langheransian cell histiocytosis (LCH) is a ra...
# 5  20211116  A 55-year-old male with a past medical history...
# 6  20211116  Antineutrophil cytoplasmic antibody (ANCA) is ...
# 7  20211116  A 67-year-old female presented with a chief co...
# 8  20211116  Neurosyphilis is a disease caused by systemic ...
# 9  20211117  Merkel cell carcinoma (MCC) is a rare but high...
#
#                                  DOI  Year Month  Day
# 0  10.1093/ptj/pzaa194 [doi] pzaa194   NaN   NaN  NaN
# 1  10.7759/cureus.19607 [doi] e19607  2021    11   15
# 2  10.7759/cureus.19608 [doi] e19608  2021    11   15
# 3  10.7759/cureus.19612 [doi] e19612  2021    11   15
# 4  10.7759/cureus.19617 [doi] e19617  2021    11   16
# 5  10.7759/cureus.19635 [doi] e19635  2021    11   16
# 6  10.7759/cureus.19616 [doi] e19616  2021    11   16
# 7  10.7759/cureus.19646 [doi] e19646  2021    11   16
# 8  10.7759/cureus.19631 [doi] e19631  2021    11   16
# 9  10.7759/cureus.19659 [doi] e19659  2021    11   17

# %%
# make sure PMIDs in df are numeric like patients_df
df['PMID'] = pd.to_numeric(df['PMID'], errors='coerce').dropna().astype(int)

print("patients_df PMID dtype:", patients_df['PMID'].dtype)
print("df PMID dtype:", df['PMID'].dtype)
print("records fetched into df:", len(df))

# count missing
missing_pmids = patients_df[~patients_df['PMID'].isin(df['PMID'])]
print(f"Number of missing PMIDs: {len(missing_pmids)}")
print(missing_pmids.head())
# Out:
# patients_df PMID dtype: int64
# df PMID dtype: int32
# records fetched into df: 140811
# Number of missing PMIDs: 90
#       patient_id patient_uid      PMID                         file_path  \
# 2207        2207   6110280-1  30159206  comm/PMC006xxxxxx/PMC6110280.xml
# 2208        2208   6110280-2  30159206  comm/PMC006xxxxxx/PMC6110280.xml
# 2209        2209   6110280-3  30159206  comm/PMC006xxxxxx/PMC6110280.xml
# 3219        3219   6173321-1  30294454  comm/PMC006xxxxxx/PMC6173321.xml
# 7145        7145   6424340-1  30899779  comm/PMC006xxxxxx/PMC6424340.xml
#
#                                                   title  \
# 2207  Tacrolimus-Induced Remission in Drug Resistant...
# 2208  Tacrolimus-Induced Remission in Drug Resistant...
# 2209  Tacrolimus-Induced Remission in Drug Resistant...
# 3219  Malignant Pleural Mesothelioma presenting with...
# 7145  A Rare Case of HIV-Induced Inflammatory Demyel...
#
#                                                 patient               age  \
# 2207  42-year-old man presented with proximal muscle...  [[42.0, 'year']]
# 2208  39-year-old man with history of dermatomyositi...  [[39.0, 'year']]
# 2209  51-year-old woman with a history of hypertensi...  [[51.0, 'year']]
# 3219  A 71 year-old-male with past medical history o...  [[71.0, 'year']]
# 7145  A 23-year-old male presented with lumbar back ...  [[23.0, 'year']]
#
#      gender                                  relevant_articles  \
# 2207      M  {'23124935': 1, '16157605': 1, '17881720': 1, ...
# 2208      M  {'23124935': 1, '16157605': 1, '17881720': 1, ...
# 2209      F  {'23124935': 1, '16157605': 1, '17881720': 1, ...
# 3219      M  {'948545': 1, '6202538': 1, '10049665': 1, '70...
# 7145      M  {'15834034': 1, '23642721': 1, '15800230': 1, ...
#
#                                        similar_patients
# 2207                   {'6110280-2': 2, '6110280-3': 2}
# 2208                   {'6110280-1': 2, '6110280-3': 2}
# 2209                   {'6110280-1': 2, '6110280-2': 2}
# 3219                                                 {}
# 7145  {'2629480-1': 1, '3336224-1': 1, '8371896-1': ...
